# %%
print("Hello world!")
# Out:
# Hello world!

# %%
import pandas as pd

# %%
import csv

# Data to save
data = [
    ["Name", "Age", "City"],
    ["Aarav", 2, "Mumbai"],
    ["Sofia", 1, "Delhi"],
    ["Liam", 3, "Bangalore"]
]

# Create babies.csv file
with open("babies.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(data)

print("babies.csv file created successfully!")
# Out:
# babies.csv file created successfully!

# %%
import csv

data = [
    ["bwt","gestation","parity","age","height","weight","smoke"],
    [120,284,0,27,62,100,0],
    [113,282,0,33,64,135,0],
    [128,279,0,28,64,115,1],
    [123,999,0,36,69,190,0],
    [108,282,0,23,67,125,1],
    [136,286,0,25,62,93,0],
    [138,244,0,33,62,178,0],
    [132,245,0,23,65,140,0],
    [120,289,0,25,62,125,0],
    [143,299,0,30,66,136,1],
    [140,351,0,27,68,120,0],
    [144,282,0,32,64,124,1],
    [141,279,0,23,63,128,1],
    [110,281,0,36,61,99,1]
]

with open("babies.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerows(data)

print("babies.csv created.")
# Out:
# babies.csv created.

# %%
df = pd.read_csv("dataset/babies.csv")
df.head()
# Out:
#    bwt  gestation  parity  age  height  weight  smoke
# 0  120        284       0   27      62     100      0
# 1  113        282       0   33      64     135      0
# 2  128        279       0   28      64     115      1
# 3  123        999       0   36      69     190      0
# 4  108        282       0   23      67     125      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bwt        14 non-null     int64
#  1   gestation  14 non-null     int64
#  2   parity     14 non-null     int64
#  3   age        14 non-null     int64
#  4   height     14 non-null     int64
#  5   weight     14 non-null     int64
#  6   smoke      14 non-null     int64
# dtypes: int64(7)
# memory usage: 916.0 bytes

# %%
df.describe()
# Out:
#               bwt   gestation  parity        age     height      weight  \
# count   14.000000   14.000000    14.0  14.000000  14.000000   14.000000
# mean   128.285714  334.428571     0.0  28.642857  64.214286  129.142857
# std     12.633463  192.864526     0.0   4.700362   2.486226   27.315414
# min    108.000000  244.000000     0.0  23.000000  61.000000   93.000000
# 25%    120.000000  279.500000     0.0  25.000000  62.000000  116.250000
# 50%    130.000000  282.000000     0.0  27.500000  64.000000  125.000000
# 75%    139.500000  288.250000     0.0  32.750000  65.750000  135.750000
# max    144.000000  999.000000     0.0  36.000000  69.000000  190.000000
#
#            smoke
# count  14.000000
# mean    0.428571
# std     0.513553
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     1.000000
# max     1.000000

# %%
df.isnull().sum()
# Out:
# bwt          0
# gestation    0
# parity       0
# age          0
# height       0
# weight       0
# smoke        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# bwt          0
# gestation    0
# parity       0
# age          0
# height       0
# weight       0
# smoke        0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['bwt', 'gestation', 'parity', 'age', 'height', 'weight', 'smoke'], dtype='object')

# %%
plt.scatter(df['gestation'],df['bwt'])
plt.xlabel("Gestation")
plt.ylabel("Birth Weight")
plt.show()

# %%
plt.scatter(df['weight'],df['bwt'])
plt.xlabel("mother's weight")
plt.ylabel("Birth weight")
plt.show()

# %%
df.columns
# Out:
# Index(['bwt', 'gestation', 'parity', 'age', 'height', 'weight', 'smoke'], dtype='object')

# %%
plt.scatter(df['age'], df['bwt'])
plt.xlabel("Mother's age")
plt.ylabel("Birth Weight")
plt.show()

# %%
df.columns
# Out:
# Index(['bwt', 'gestation', 'parity', 'age', 'height', 'weight', 'smoke'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bwt        14 non-null     int64
#  1   gestation  14 non-null     int64
#  2   parity     14 non-null     int64
#  3   age        14 non-null     int64
#  4   height     14 non-null     int64
#  5   weight     14 non-null     int64
#  6   smoke      14 non-null     int64
# dtypes: int64(7)
# memory usage: 916.0 bytes

# %%
df
# Out:
#     bwt  gestation  parity  age  height  weight  smoke
# 0   120        284       0   27      62     100      0
# 1   113        282       0   33      64     135      0
# 2   128        279       0   28      64     115      1
# 3   123        999       0   36      69     190      0
# 4   108        282       0   23      67     125      1
# 5   136        286       0   25      62      93      0
# 6   138        244       0   33      62     178      0
# 7   132        245       0   23      65     140      0
# 8   120        289       0   25      62     125      0
# 9   143        299       0   30      66     136      1
# 10  140        351       0   27      68     120      0
# 11  144        282       0   32      64     124      1
# 12  141        279       0   23      63     128      1
# 13  110        281       0   36      61      99      1

# %%
df['smoke'].unique()
# Out:
# array([0, 1])

# %%
df['smoke'].value_counts()
# Out:
# smoke
# 0    8
# 1    6
# Name: count, dtype: int64

# %%
df['smoke'].value_counts(normalize=True)*100
# Out:
# smoke
# 0    57.142857
# 1    42.857143
# Name: proportion, dtype: float64

# %%
df['parity'].unique()
# Out:
# array([0])

# %%
df['parity'].value_counts()
# Out:
# parity
# 0    14
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#                 bwt  gestation  parity       age    height    weight     smoke
# bwt        1.000000  -0.104205     NaN -0.138052  0.081168  0.142311  0.050813
# gestation -0.104205   1.000000     NaN  0.440914  0.602659  0.594369 -0.236542
# parity          NaN        NaN     NaN       NaN       NaN       NaN       NaN
# age       -0.138052   0.440914     NaN  1.000000  0.020217  0.385665  0.004552
# height     0.081168   0.602659     NaN  0.020217  1.000000  0.467313 -0.017213
# weight     0.142311   0.594369     NaN  0.385665  0.467313  1.000000 -0.262428
# smoke      0.050813  -0.236542     NaN  0.004552 -0.017213 -0.262428  1.000000

# %%
y = df['bwt']

# %%
x = df.iloc[:,1:]
x
# Out:
#     gestation  parity  age  height  weight  smoke
# 0         284       0   27      62     100      0
# 1         282       0   33      64     135      0
# 2         279       0   28      64     115      1
# 3         999       0   36      69     190      0
# 4         282       0   23      67     125      1
# 5         286       0   25      62      93      0
# 6         244       0   33      62     178      0
# 7         245       0   23      65     140      0
# 8         289       0   25      62     125      0
# 9         299       0   30      66     136      1
# 10        351       0   27      68     120      0
# 11        282       0   32      64     124      1
# 12        279       0   23      63     128      1
# 13        281       0   36      61      99      1

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train, x_test, y_train, y_test = tts(x, y, test_size=0.20)

# %%
x_train.shape
# Out:
# (11, 6)

# %%
x_test.shape
# Out:
# (3, 6)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
lr = LinearRegression()
lasso = Lasso()
rigde = Ridge()

# %%
lr.fit(x_train, y_train)
lasso.fit(x_train, y_train)
rigde.fit(x_train, y_train)
# Out:
# Ridge()

# %%
lr_pred = lr.predict(x_test)
las_pred = lasso.predict(x_test)
rid_pred = rigde.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
lr_rscore = r2_score(y_test, lr_pred)
las_rscore = r2_score(y_test, las_pred)
rid_rscore = r2_score(y_test, rid_pred)

# %%
lr_mse = mean_squared_error(y_test, lr_pred)
las_mse = mean_squared_error(y_test, las_pred)
rid_mse = mean_squared_error(y_test, rid_pred)

# %%
print("\nPerformance of Linear Regression Model :")
print("R2score :", lr_rscore)
print("MSE: ", lr_mse)
# Out:
# Performance of Linear Regression Model :
# R2score : -1.7854775289190195
# MSE:  623.9469664778604

# %%
print("\nPerformance of Lasso Regression Model :")
print("R2score :", las_rscore)
print("MSE: ", las_mse)
# Out:
# Performance of Lasso Regression Model :
# R2score : -1.5104593151419992
# MSE:  562.3428865918078

# %%
print("\nPerformance of Ridge Regression Model")
print("R2score :", rid_rscore)
print("MSE: ", rid_mse)
# Out:
# Performance of Ridge Regression Model
# R2score : -1.7082346502230683
# MSE:  606.6445616499673

# %%
import pickle

# %%
with open("model/model.pkl", 'wb') as f:
    pickle.dump(lr,f)

# %%
with open("model/model.pkl", 'rb') as obj:
    mymodel = pickle.load(obj)

# %%
x_train.head()
# Out:
#     gestation  parity  age  height  weight  smoke
# 12        279       0   23      63     128      1
# 0         284       0   27      62     100      0
# 5         286       0   25      62      93      0
# 6         244       0   33      62     178      0
# 7         245       0   23      65     140      0

# %%
test_data = {
   "gestation" : [279],
    "parity"  : [0],
    "age" : [23],
    "height" : [63],
    "weight" : [128],
    "smoke" : [1]
}

# %%
test_df = pd.DataFrame(test_data)
test_df
# Out:
#    gestation  parity  age  height  weight  smoke
# 0        279       0   23      63     128      1

# %%
mymodel.predict(test_df)
# Out:
# array([141.8138776])
